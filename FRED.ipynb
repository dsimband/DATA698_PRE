# %% [markdown]
# # FRED

# %%
from fredapi import Fred
fred = Fred(api_key='c0a3f23bdd23a65e6546b6d0e5f4d4a5')
data = fred.get_series('SP500')

# %%
data
# Out:
# 2013-06-03    1640.42
# 2013-06-04    1631.38
# 2013-06-05    1608.90
# 2013-06-06    1622.56
# 2013-06-07    1643.38
#                ...
# 2023-05-29        NaN
# 2023-05-30    4205.52
# 2023-05-31    4179.83
# 2023-06-01    4221.02
# 2023-06-02    4282.37
# Length: 2610, dtype: float64

# %%
df = fred.search_by_category(101, limit=100, order_by='popularity', sort_order='desc')
df['title']
# Out:
# series id
# TERMCBCCALLNS      Commercial Bank Interest Rate on Credit Card P...
# TOTALSL                  Total Consumer Credit Owned and Securitized
# TERMCBAUTO48NS     Finance Rate on Consumer Installment Loans at ...
# REVOLSL              Revolving Consumer Credit Owned and Securitized
# SLOAS                            Student Loans Owned and Securitized
#                                          ...
# DTCNLNHFNM         Nonrevolving Consumer Credit Securitized by Fi...
# DTCTLNHNXDFBANM    Nonrevolving Consumer Credit Owned and Securit...
# NREVNDI            Nonrevolving Consumer Credit Owned by Deposito...
# DTCNLHNNM          Total Consumer Credit Securitized by Nonfinanc...
# OTHERSL                Total Other Credit Outstanding (DISCONTINUED)
# Name: title, Length: 100, dtype: object

# %%
df
# Out:
#                               id realtime_start realtime_end  \
# series id
# TERMCBCCALLNS      TERMCBCCALLNS     2023-06-04   2023-06-04
# TOTALSL                  TOTALSL     2023-06-04   2023-06-04
# TERMCBAUTO48NS    TERMCBAUTO48NS     2023-06-04   2023-06-04
# REVOLSL                  REVOLSL     2023-06-04   2023-06-04
# SLOAS                      SLOAS     2023-06-04   2023-06-04
# ...                          ...            ...          ...
# DTCNLNHFNM            DTCNLNHFNM     2023-06-04   2023-06-04
# DTCTLNHNXDFBANM  DTCTLNHNXDFBANM     2023-06-04   2023-06-04
# NREVNDI                  NREVNDI     2023-06-04   2023-06-04
# DTCNLHNNM              DTCNLHNNM     2023-06-04   2023-06-04
# OTHERSL                  OTHERSL     2023-06-04   2023-06-04
#
#                                                              title  \
# series id
# TERMCBCCALLNS    Commercial Bank Interest Rate on Credit Card P...
# TOTALSL                Total Consumer Credit Owned and Securitized
# ...

# %%
data = fred.get_series('DFEDTARL')
data
# Out:
# 2008-12-16    0.0
# 2008-12-17    0.0
# 2008-12-18    0.0
# 2008-12-19    0.0
# 2008-12-20    0.0
#              ...
# 2023-05-31    5.0
# 2023-06-01    5.0
# 2023-06-02    5.0
# 2023-06-03    5.0
# 2023-06-04    5.0
# Length: 5284, dtype: float64
